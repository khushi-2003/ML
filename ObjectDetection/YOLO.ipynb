# %% [markdown]
# Object Detection using YOLO

# %%
import ultralytics

# %%
import cv2
from ultralytics import YOLO
import math

# Initialize YOLO model (downloads automatically on first run)
model = YOLO("yolov8n.pt")  # You can use 'yolov8n.pt', 'yolov8s.pt', etc.

# Open video capture (0 for webcam, or video file path)
cap = cv2.VideoCapture(0)

# COCO dataset class names (YOLO's default)
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack",
              "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball",
              "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket",
              "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
              "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake",
              "chair", "sofa", "pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop",
              "mouse", "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink",
              "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]

# %%
while True:
    success, img = cap.read()
    if not success:
        break

    # Run object detection
    results = model(img, stream=True)

    # Initialize counting dictionary
    detection_counts = {}

    # Process detection results
    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Extract bounding box coordinates
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            # Calculate confidence
            confidence = math.ceil((box.conf[0] * 100)) / 100

            # Get class name
            cls = int(box.cls[0])
            class_name = classNames[cls]

            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 2)

            # Draw label with confidence
            label = f'{class_name} {confidence:.2f}' # f'person' 98 => person  98.80
            cv2.putText(img, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 255), 2)

            # Update count for detected class
            if class_name in detection_counts:
                detection_counts[class_name] += 1
            else:
                detection_counts[class_name] = 1

    # Display counts on image on the left side corner of the image frame(one after another).
    y_offset = 30
    for obj_class, count in detection_counts.items():
        count_text = f'{obj_class}: {count}' # person : 3 , person:1,cell phone : 1, bottle:2
        cv2.putText(img, count_text, (10, y_offset),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        y_offset += 30

    # Show result
    cv2.imshow('Object Detection and Counting', img)

    # Exit on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 187.5ms
# Speed: 46.8ms preprocess, 187.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.2ms
# Speed: 4.2ms preprocess, 141.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 131.2ms
# Speed: 2.6ms preprocess, 131.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.1ms
# Speed: 2.3ms preprocess, 125.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.6ms
# Speed: 2.2ms preprocess, 125.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.1ms
# Speed: 2.3ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 129.0ms
# Speed: 2.4ms preprocess, 129.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.9ms
# Speed: 2.3ms preprocess, 128.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 127.4ms
# Speed: 2.6ms preprocess, 127.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.2ms
# Speed: 2.5ms preprocess, 125.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.3ms
# Speed: 2.8ms preprocess, 124.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.1ms
# Speed: 2.6ms preprocess, 122.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.6ms preprocess, 122.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.1ms
# Speed: 2.9ms preprocess, 123.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.7ms
# Speed: 3.8ms preprocess, 125.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 127.1ms
# Speed: 3.7ms preprocess, 127.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.9ms
# Speed: 2.7ms preprocess, 124.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.6ms
# Speed: 4.8ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.5ms
# Speed: 2.4ms preprocess, 128.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.4ms
# Speed: 2.4ms preprocess, 126.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.0ms
# Speed: 2.4ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.2ms
# Speed: 2.2ms preprocess, 122.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 118.2ms
# Speed: 2.4ms preprocess, 118.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.1ms
# Speed: 3.1ms preprocess, 118.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.5ms
# Speed: 2.5ms preprocess, 123.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.2ms
# Speed: 3.4ms preprocess, 124.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.9ms
# Speed: 2.7ms preprocess, 130.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.2ms
# Speed: 2.9ms preprocess, 121.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.5ms
# Speed: 2.9ms preprocess, 120.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.9ms
# Speed: 2.2ms preprocess, 123.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Speed: 4.2ms preprocess, 124.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.4ms
# Speed: 2.5ms preprocess, 120.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.6ms
# Speed: 2.9ms preprocess, 123.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.7ms
# Speed: 2.8ms preprocess, 128.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.9ms
# Speed: 2.8ms preprocess, 127.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.2ms
# Speed: 2.5ms preprocess, 125.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.6ms
# Speed: 2.9ms preprocess, 119.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.0ms
# Speed: 2.3ms preprocess, 126.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.6ms
# Speed: 3.9ms preprocess, 120.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.5ms
# Speed: 2.8ms preprocess, 122.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.3ms
# Speed: 2.6ms preprocess, 126.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.8ms
# Speed: 2.3ms preprocess, 127.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.9ms
# Speed: 2.7ms preprocess, 128.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 123.2ms
# Speed: 2.7ms preprocess, 123.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Speed: 2.5ms preprocess, 120.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 117.5ms
# Speed: 2.5ms preprocess, 117.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.0ms
# Speed: 4.6ms preprocess, 123.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130