# %% [markdown]
# # Simple Linear Regression
# Linear Regression model that predicts the profit of startupts on basis of Administration charges.

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Khushi Kanade\OneDrive\Desktop\Analytics\50_Startups.csv")
df.head(5)
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
#Perform basic data quality checks
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
#Separate X and Y features
X = df[['ADMIN']]
Y = df[['PROFIT']]

# %%
X.head()
# Out:
#        ADMIN
# 0  136897.80
# 1  151377.59
# 2  101145.55
# 3  118671.85
# 4   91391.77

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([76974.47130542])

# %%
#slope
model.coef_
# Out:
# array([[0.2887492]])

# %% [markdown]
# profit_pred = model.intecept_ + model.coef_ * admin

# %%
ypreds = model.predict(X)
ypreds[:5]
# Out:
# array([[116503.6018596 ],
#        [120684.62967237],
#        [106180.1681897 ],
#        [111240.87333494],
#        [103363.77199475]])

# %%
model.score(X,Y)
# Out:
# 0.04028714077757223

# %% [markdown]
# # Performance Metrics

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#MSE 
mse = mean_squared_error(Y,ypreds)
print(f"MSE : {mse}")
# Out:
# MSE : 1527955397.744143

# %%
# RMSE
rmse = mse**0.5
print(f"RMSE : {rmse}")
# Out:
# RMSE : 39089.07005473708

# %%
mae = mean_absolute_error(Y,ypreds)
print(f"MAE : {mae}")
# Out:
# MAE : 30659.814789071817

# %%
#R2 score
r2 = r2_score(Y,ypreds)
print(f"R2 score: {r2}")
# Out:
# R2 score: 0.04028714077757223

# %% [markdown]
# Since the R² score is near zero, the model fails to capture the underlying relationship in the data. Hence, it is not suitable.

# %% [markdown]
# # Simple Linear Regression
# Linear Regression model that predicts the profit of startupts on basis of RnD charges.

# %%
#Separate X and Y features
X = df[['RND']]
Y = df[['PROFIT']]

# %%
X.head()
# Out:
#          RND
# 0  165349.20
# 1  162597.70
# 2  153441.51
# 3  144372.41
# 4  142107.34

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([49032.89914125])

# %%
model.coef_
# Out:
# array([[0.85429137]])

# %%
Ypred = model.predict(X)
Ypred[:5]
# Out:
# array([[190289.29389289],
#        [187938.71118575],
#        [180116.65707807],
#        [172369.00320589],
#        [170433.97345032]])

# %%
model.score(X,Y)
# Out:
# 0.9465353160804393

# %%
#Performance metrics
mse = mean_squared_error(Y,Ypred)
rmse = mse**0.5
mae = mean_absolute_error(Y,Ypred)
r2 = r2_score(Y,Ypred)

print(f" MSE : {mse} \n RMSE : {rmse} \n MAE : {mae} \n R2 score : {r2}")
# Out:
#  MSE : 85120931.32706906
#  RMSE : 9226.100548285232
#  MAE : 6910.98435457961
#  R2 score : 0.9465353160804393

# %% [markdown]
# Since the R² score is more than 0.8 , the model captures the underlying relationship in the data well. Hence, we can go with this model.
